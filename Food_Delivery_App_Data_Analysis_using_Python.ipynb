# %% [markdown]
# **CREATE DATASET / LOAD DATASET**

# %%
import pandas as pd

data = {
    "Order_ID": [1,2,3,4,5,6,7],
    "Order_Date": pd.to_datetime([
        "2024-01-05","2024-01-06","2024-01-07",
        "2024-01-08","2024-01-09","2024-01-10","2024-01-11"
    ]),
    "City": ["Delhi","Delhi","Mumbai","Pune","Mumbai","Delhi","Pune"],
    "Delivery_Partner": ["Zomato","Swiggy","Zomato","Swiggy","Zomato","Zomato","Swiggy"],
    "Distance_km": [5.2, 8.5, 3.1, 6.4, 4.8, 10.2, 5.5],
    "Delivery_Time": [30,45,25,40,35,50,28],
    "Order_Value": [450, 700, 380, 520, 600, 800, 420],
    "Rating": [4.5,3.8,4.7,4.0,4.2,3.5,4.6]
}

# %%
df = pd.DataFrame(data);

# %%
df
# Out:
#    Order_ID Order_Date    City Delivery_Partner  Distance_km  Delivery_Time  \
# 0         1 2024-01-05   Delhi           Zomato          5.2             30
# 1         2 2024-01-06   Delhi           Swiggy          8.5             45
# 2         3 2024-01-07  Mumbai           Zomato          3.1             25
# 3         4 2024-01-08    Pune           Swiggy          6.4             40
# 4         5 2024-01-09  Mumbai           Zomato          4.8             35
# 5         6 2024-01-10   Delhi           Zomato         10.2             50
# 6         7 2024-01-11    Pune           Swiggy          5.5             28
#
#    Order_Value  Rating
# 0          450     4.5
# 1          700     3.8
# 2          380     4.7
# 3          520     4.0
# 4          600     4.2
# 5          800     3.5
# 6          420     4.6

# %% [markdown]
# **AVERAGE DELIVERY TIME FOR EACH CITY**

# %%
city_avg_time = df.groupby("City")["Delivery_Time"].mean()
city_avg_time
# Out:
# City
# Delhi     41.666667
# Mumbai    30.000000
# Pune      34.000000
# Name: Delivery_Time, dtype: float64

# %%
city_avg_time = df.groupby("City")["Delivery_Time"].mean().round().sort_values()
city_avg_time
# Out:
# City
# Mumbai    30.0
# Pune      34.0
# Delhi     42.0
# Name: Delivery_Time, dtype: float64

# %% [markdown]
# **DOES DISTANCE IMPACTS DELIVERY TIME**

# %%
df
# Out:
#    Order_ID Order_Date    City Delivery_Partner  Distance_km  Delivery_Time  \
# 0         1 2024-01-05   Delhi           Zomato          5.2             30
# 1         2 2024-01-06   Delhi           Swiggy          8.5             45
# 2         3 2024-01-07  Mumbai           Zomato          3.1             25
# 3         4 2024-01-08    Pune           Swiggy          6.4             40
# 4         5 2024-01-09  Mumbai           Zomato          4.8             35
# 5         6 2024-01-10   Delhi           Zomato         10.2             50
# 6         7 2024-01-11    Pune           Swiggy          5.5             28
#
#    Order_Value  Rating
# 0          450     4.5
# 1          700     3.8
# 2          380     4.7
# 3          520     4.0
# 4          600     4.2
# 5          800     3.5
# 6          420     4.6

# %%
df[["Distance_km","Delivery_Time"]]
# Out:
#    Distance_km  Delivery_Time
# 0          5.2             30
# 1          8.5             45
# 2          3.1             25
# 3          6.4             40
# 4          4.8             35
# 5         10.2             50
# 6          5.5             28

# %%
df[["Distance_km","Delivery_Time"]].corr()
# Out:
#                Distance_km  Delivery_Time
# Distance_km       1.000000       0.936247
# Delivery_Time     0.936247       1.000000

# %%
import seaborn as sns
plt = sns.heatmap(df[["Distance_km","Delivery_Time","Order_Value"]].corr(),annot=True)

# %% [markdown]
# **DOES FAST DELIVERY LEADS TO BETTER RATING**

# %%
df
# Out:
#    Order_ID Order_Date    City Delivery_Partner  Distance_km  Delivery_Time  \
# 0         1 2024-01-05   Delhi           Zomato          5.2             30
# 1         2 2024-01-06   Delhi           Swiggy          8.5             45
# 2         3 2024-01-07  Mumbai           Zomato          3.1             25
# 3         4 2024-01-08    Pune           Swiggy          6.4             40
# 4         5 2024-01-09  Mumbai           Zomato          4.8             35
# 5         6 2024-01-10   Delhi           Zomato         10.2             50
# 6         7 2024-01-11    Pune           Swiggy          5.5             28
#
#    Order_Value  Rating
# 0          450     4.5
# 1          700     3.8
# 2          380     4.7
# 3          520     4.0
# 4          600     4.2
# 5          800     3.5
# 6          420     4.6

# %%
df[["Rating","Delivery_Time"]]
# Out:
#    Rating  Delivery_Time
# 0     4.5             30
# 1     3.8             45
# 2     4.7             25
# 3     4.0             40
# 4     4.2             35
# 5     3.5             50
# 6     4.6             28

# %%
df[["Rating","Delivery_Time"]].corr()
# Out:
#                  Rating  Delivery_Time
# Rating         1.000000      -0.997906
# Delivery_Time -0.997906       1.000000

# %%
plt = sns.heatmap(df[["Rating","Delivery_Time"]].corr(),annot=True)

# %% [markdown]
# **WHICH DELIVERY PARTNER IS FASTER**

# %%
df
# Out:
#    Order_ID Order_Date    City Delivery_Partner  Distance_km  Delivery_Time  \
# 0         1 2024-01-05   Delhi           Zomato          5.2             30
# 1         2 2024-01-06   Delhi           Swiggy          8.5             45
# 2         3 2024-01-07  Mumbai           Zomato          3.1             25
# 3         4 2024-01-08    Pune           Swiggy          6.4             40
# 4         5 2024-01-09  Mumbai           Zomato          4.8             35
# 5         6 2024-01-10   Delhi           Zomato         10.2             50
# 6         7 2024-01-11    Pune           Swiggy          5.5             28
#
#    Order_Value  Rating
# 0          450     4.5
# 1          700     3.8
# 2          380     4.7
# 3          520     4.0
# 4          600     4.2
# 5          800     3.5
# 6          420     4.6

# %%
df.groupby("Delivery_Partner")["Delivery_Time"].mean().reset_index()
# Out:
#   Delivery_Partner  Delivery_Time
# 0           Swiggy      37.666667
# 1           Zomato      35.000000

# %% [markdown]
# **WHICH CITY GIVES THE BEST CUSTOMER EXPERIENCE**

# %%
df
# Out:
#    Order_ID Order_Date    City Delivery_Partner  Distance_km  Delivery_Time  \
# 0         1 2024-01-05   Delhi           Zomato          5.2             30
# 1         2 2024-01-06   Delhi           Swiggy          8.5             45
# 2         3 2024-01-07  Mumbai           Zomato          3.1             25
# 3         4 2024-01-08    Pune           Swiggy          6.4             40
# 4         5 2024-01-09  Mumbai           Zomato          4.8             35
# 5         6 2024-01-10   Delhi           Zomato         10.2             50
# 6         7 2024-01-11    Pune           Swiggy          5.5             28
#
#    Order_Value  Rating
# 0          450     4.5
# 1          700     3.8
# 2          380     4.7
# 3          520     4.0
# 4          600     4.2
# 5          800     3.5
# 6          420     4.6

# %%
df.groupby("City")["Rating"].mean().round(2).sort_values(ascending=False)
# Out:
# City
# Mumbai    4.45
# Pune      4.30
# Delhi     3.93
# Name: Rating, dtype: float64

# %% [markdown]
# **ARE HIGH VALUE ORDERS GETTING BETTER RATING**

# %%
df
# Out:
#    Order_ID Order_Date    City Delivery_Partner  Distance_km  Delivery_Time  \
# 0         1 2024-01-05   Delhi           Zomato          5.2             30
# 1         2 2024-01-06   Delhi           Swiggy          8.5             45
# 2         3 2024-01-07  Mumbai           Zomato          3.1             25
# 3         4 2024-01-08    Pune           Swiggy          6.4             40
# 4         5 2024-01-09  Mumbai           Zomato          4.8             35
# 5         6 2024-01-10   Delhi           Zomato         10.2             50
# 6         7 2024-01-11    Pune           Swiggy          5.5             28
#
#    Order_Value  Rating
# 0          450     4.5
# 1          700     3.8
# 2          380     4.7
# 3          520     4.0
# 4          600     4.2
# 5          800     3.5
# 6          420     4.6

# %%
df[["Order_Value","Rating"]].sort_values(["Order_Value","Rating"],ascending=[False,False])
# Out:
#    Order_Value  Rating
# 5          800     3.5
# 1          700     3.8
# 4          600     4.2
# 3          520     4.0
# 0          450     4.5
# 6          420     4.6
# 2          380     4.7

# %%
df[["Order_Value","Rating"]].corr()
# Out:
#              Order_Value    Rating
# Order_Value     1.000000 -0.956032
# Rating         -0.956032  1.000000

# %% [markdown]
# **WHICH DAY OF THE WEEK HAS WORST DELIVERY EXPERIENCE**

# %%
df
# Out:
#    Order_ID Order_Date    City Delivery_Partner  Distance_km  Delivery_Time  \
# 0         1 2024-01-05   Delhi           Zomato          5.2             30
# 1         2 2024-01-06   Delhi           Swiggy          8.5             45
# 2         3 2024-01-07  Mumbai           Zomato          3.1             25
# 3         4 2024-01-08    Pune           Swiggy          6.4             40
# 4         5 2024-01-09  Mumbai           Zomato          4.8             35
# 5         6 2024-01-10   Delhi           Zomato         10.2             50
# 6         7 2024-01-11    Pune           Swiggy          5.5             28
#
#    Order_Value  Rating
# 0          450     4.5
# 1          700     3.8
# 2          380     4.7
# 3          520     4.0
# 4          600     4.2
# 5          800     3.5
# 6          420     4.6

# %%
df["Day"] = df['Order_Date'].dt.day_name()

# %%
df
# Out:
#    Order_ID Order_Date    City Delivery_Partner  Distance_km  Delivery_Time  \
# 0         1 2024-01-05   Delhi           Zomato          5.2             30
# 1         2 2024-01-06   Delhi           Swiggy          8.5             45
# 2         3 2024-01-07  Mumbai           Zomato          3.1             25
# 3         4 2024-01-08    Pune           Swiggy          6.4             40
# 4         5 2024-01-09  Mumbai           Zomato          4.8             35
# 5         6 2024-01-10   Delhi           Zomato         10.2             50
# 6         7 2024-01-11    Pune           Swiggy          5.5             28
#
#    Order_Value  Rating        Day
# 0          450     4.5     Friday
# 1          700     3.8   Saturday
# 2          380     4.7     Sunday
# 3          520     4.0     Monday
# 4          600     4.2    Tuesday
# 5          800     3.5  Wednesday
# 6          420     4.6   Thursday

# %%
df.groupby("Day")["Rating"].mean().reset_index().sort_values("Rating",ascending=False)
# Out:
#          Day  Rating
# 3     Sunday     4.7
# 4   Thursday     4.6
# 0     Friday     4.5
# 5    Tuesday     4.2
# 1     Monday     4.0
# 2   Saturday     3.8
# 6  Wednesday     3.5
